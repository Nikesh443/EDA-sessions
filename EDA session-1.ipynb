# %%
######## Packages of EDA ###############   Hi I am nikesh

# %%
1) Pandas: dataframe analysis

2) numpy: Numerical python/Number python

3) matplotlib: plotting

4) seaborn: plot

5) plotly: plot

6) bokhe: plot

# %%
###### Packages of ML ##########

# %%
1)scikit-learn: sklearn

# %%
##### Packages of Deep learning #####

# %%
1) Tensorflow

2) keras

3) pytorch

4) CV (computer vision)

# %%
### Packages of NLP #####

# %%
1) NLTK

2) scipy

# %%
### Generative AI ####

# %%
1) chatgpt: openAI

2) makersuit: google generative ai

3) Amazon Q

# %%
### Hugging face transformer (BERT)#####

# %%
1) Transformer

# %%
## other packages###
random
math
os
sys
time

# %%
#### AZure ML #####
1) Azure packages
2) GCP vertex ai
3) aws sage maker

# %% [markdown]
# ## step1: Import required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## step2: Read the data

# %% [markdown]
# $visa data set$

# %%
# file location
# file name
# extension

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
pd.read_csv(file_path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $bank data$

# %%
file_path2="C:\\Users\\pc\\Documents\\bank.csv"
pd.read_csv(file_path2,sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# ## step-3: create a dataframe using lists

# %%
list1=['Ram','Raheem','Robert']
list2=[30,31,32]
Nikesh=pd.DataFrame(zip(list1,list2),columns=['Name','Age'])  # or you can use separate variables name cols=['Name','Age'] and use it

# %%
Nikesh
# In python index starts with zero
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# ## step4: How to save the data frame in local

# %%
# What is your data frame name: Nikesh
# Where you want to save : "C:\Users\pc\Documents"
# What name you want to provide : NIKESH
Nikesh.to_csv("C:\\Users\\pc\\Documents\\NIKESH.csv")

# %%
Nikesh.to_csv("NIKESH.cv")  # This will save where python file is located

# %%
Nikesh.to_csv("C:\\Users\\pc\\Documents\\NIKESH1.csv",index=False)

# It will not create extra column as index

# %% [markdown]
# $ Task-1: read Nikesh and Nikesh1 data$

# %%
file_path3="C:\\Users\\pc\\Documents\\NIKESH.csv"
pd.read_csv(file_path3)
# How can we avoid unnamed 0
# Out:
#    Unnamed: 0    Name  Age
# 0           0     Ram   30
# 1           1  Raheem   31
# 2           2  Robert   32

# %%
file_path4="C:\\Users\\pc\\Documents\\NIKESH1.csv"
pd.read_csv(file_path4)
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %% [markdown]
# ## Step-5: add a new column to a existing data frame

# %%
Nikesh

# What is you data frame name= Nikesh
# what is the name of the column you want to add= city
# How many rows we have in original data=3
# What is your new data=['Hyd','chennai','Blr']
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
Nikesh['city']=['Hyd','chennai','Blr']

# %%
Nikesh
# Out:
#      Name  Age     city
# 0     Ram   30      Hyd
# 1  Raheem   31  chennai
# 2  Robert   32      Blr

# %% [markdown]
# ## step-6: How to drop

# %%
# What is your data frame name: Nikesh
******** axis **********
# I want to drop column
# axis=1 =============> columns                    imp for interview
# axis=0 =============> rows
    ********* inplace ************
# What is the name of the column
# When you are drop  the column means you are modifying the table
# The data frame should be overwrite or you want to create a data frame

# inplace-TRUE means data will be overwrite

# %%
Nikesh.drop('city',
           axis=1,
           inplace=True)

# %%
Nikesh
# Out:
#      Name  Age
# 0     Ram   30
# 1  Raheem   31
# 2  Robert   32

# %%
- How to read csv data
- How to create the data using list
- how to add the column
- how to drop the column

# %% [markdown]
# ## How to create a data frame using dictionary

# %%
dict1={'Names':['Ram','Raheem','Robert'],
      'Age':[30,31,32]}
dict1
# Out:
# {'Names': ['Ram', 'Raheem', 'Robert'], 'Age': [30, 31, 32]}

# %%
pd.DataFrame(dict1,index=['A','B','C'])
# Keys automatically becomes column
# values becomes rows
# Out:
#     Names  Age
# A     Ram   30
# B  Raheem   31
# C  Robert   32

# %%
- If I give list or dict
- You need able to create a dataframe
