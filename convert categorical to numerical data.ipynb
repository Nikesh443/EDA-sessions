# %%
# Import packages and read the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - In machine learning algorithms will develop models by using maths
#
# - Maths allows only numbers
#
# - so it is very important, you need to pass numerical data only
#
# - so, we need to convert categorical data to numerical data
#
# - For that, we have encoding methods:
#
#                    - Lable encoder:
#
#                                        - map method
#
#                                        - np.where
#
#                                        - lable encoder package from sklearn
#
#                    - one hot encoder:
#
#
#                                         - pd.get_dummies()

# %% [markdown]
# - Read any categorical column: case_status
#
# - check how many unique lables are there
#
# - create a dictionary with those unique lables as keys by providing a number as values

# %%
visa_df['case_status'].unique()
dict1={'Certified':1,'Denied':0}
visa_df['case_status'].map(dict1)


# 1 ==========================> Certified
# 0===========================> Denied


# do you want to create a new column or overwrite existed column?
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: case_status, Length: 25480, dtype: int64

# %% [markdown]
# ### Create a new column

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)

###########################################################

visa_df['case_status'].unique()
dict1={'Certified':1,'Denied':0}
visa_df['case_status_num']=visa_df['case_status'].map(dict1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## drop

# %%
visa_df.drop('case_status_num',
            axis=1,          # Axis=1(for columns),Axis=0(for rows)
            inplace=True)      # inplace=True mean we are saving in the same data frame

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### Overwrite in same column(preferable)

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)

###########################################################

visa_df['case_status'].unique()
dict1={'Certified':1,'Denied':0}
visa_df['case_status']=visa_df['case_status'].map(dict1)

# In the map method there is no inplace =True

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
A=dict(visa_df.dtypes)
cat=[i for i in A if A[i]=='O']
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position']

# %%
labels=visa_df['continent'].unique()
num=len(visa_df['continent'].unique())
dict1={}
for i in range(num):
    dict1[labels[i]]=i

dict1
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
{labels[i]:i for i in range(num) }
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %% [markdown]
# ## Method-2: np.where

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
- np.where() is applicable for binary condns

- which means only applicable for two lables

- np.where(<condn>,<True_value>,<False_value>)

# %%
visa_df['case_status']=np.where(visa_df['case_status'].values=='Certified',1,0)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## Label Encoder

# %% [markdown]
# - LabelEncoder is a method from sklearn
#
# - Under sklearn we have submodules
#
# - one of the sub module: preprocessing
#
# - Any sklearn packages we have only 3 steps
#
# - step-1 : Read the package
#
# - step-2: save the package
#
# - step-3: Apply fit transform

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# step-1
from sklearn.preprocessing import LabelEncoder

# step-2:
le=LabelEncoder()
# step-3:
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ### fit_transform

# %% [markdown]
# - fit and transform two diff definations
#
# age
# 1
# 2
# 3
# 4
# 5
#
# - new age : by adding each observation with mean value: x+mean
#
# - mean=1+2+3+4+5/5=3 ===============> fit
#
# - new age =================> Transform
# 1+3
# 2+3
# 3+3
# 4+3
# 5+3

# %%
import random
random.randint(10,20)
# Out:
# 14

# %%
from random import randint
randint(10,30)
# Out:
# 10

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df.head(20)
# Out:
#    case_id  continent education_of_employee has_job_experience  \
# 0   EZYV01          1           High School                  N
# 1   EZYV02          1              Master's                  Y
# 2   EZYV03          1            Bachelor's                  N
# 3   EZYV04          1            Bachelor's                  N
# 4   EZYV05          0              Master's                  Y
# 5   EZYV06          1              Master's                  Y
# 6   EZYV07          1            Bachelor's                  N
# 7   EZYV08          3            Bachelor's                  Y
# 8   EZYV09          1            Bachelor's                  N
# 9   EZYV10          2             Doctorate                  Y
# 10  EZYV11          1              Master's                  N
# 11  EZYV12          1           High School                  Y
# 12  EZYV13          1            Bachelor's                  Y
# 13  EZYV14          1            Bachelor's                  Y
# ...

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
#######################################################################################################################3
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df.head(20)
# Out:
#    case_id  continent education_of_employee has_job_experience  \
# 0   EZYV01          1           High School                  N
# 1   EZYV02          1              Master's                  Y
# 2   EZYV03          1            Bachelor's                  N
# 3   EZYV04          1            Bachelor's                  N
# 4   EZYV05          0              Master's                  Y
# 5   EZYV06          1              Master's                  Y
# 6   EZYV07          1            Bachelor's                  N
# 7   EZYV08          3            Bachelor's                  Y
# 8   EZYV09          1            Bachelor's                  N
# 9   EZYV10          2             Doctorate                  Y
# 10  EZYV11          1              Master's                  N
# 11  EZYV12          1           High School                  Y
# 12  EZYV13          1            Bachelor's                  Y
# 13  EZYV14          1            Bachelor's                  Y
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])
visa_df['case_status']=le.inverse_transform(visa_df['case_status'])
visa_df.head(20)
# Out:
#    case_id  continent education_of_employee has_job_experience  \
# 0   EZYV01          1           High School                  N
# 1   EZYV02          1              Master's                  Y
# 2   EZYV03          1            Bachelor's                  N
# 3   EZYV04          1            Bachelor's                  N
# 4   EZYV05          0              Master's                  Y
# 5   EZYV06          1              Master's                  Y
# 6   EZYV07          1            Bachelor's                  N
# 7   EZYV08          3            Bachelor's                  Y
# 8   EZYV09          1            Bachelor's                  N
# 9   EZYV10          2             Doctorate                  Y
# 10  EZYV11          1              Master's                  N
# 11  EZYV12          1           High School                  Y
# 12  EZYV13          1            Bachelor's                  Y
# 13  EZYV14          1            Bachelor's                  Y
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## one hot encoder

# %% [markdown]
# - It means at a time only one will be ON(1/True), others are OFF(0/False)
#
# - suppose case_status has two unique lables
#
# - certified and denied
#
# - In one hot encoder it will create two new columns
#
# - like below
#
#
# |case_status|certified|denied|
# |-----------|---------|------|
# |certified|1|0|
# |denied|0|1|
#
# ### Advantages
#
# - one hot encoder new columns are orthogonal each other
#
# - orthogonality means 90 degrees phase shift
#
# - 90 degree phase shift means perpendicular to each other
#
# - Independent means no relation
#
# - It is very important property to avoid relation between variables
#
# ## Draw back
#
# - Assume that you have 100 unique lables for a column
#
# - so it will create 100 new columns
#
# - To process 100 columns we require more memory,more time, more hardware
#
# - This is called curse of dimensionality

# %% [markdown]
# ## pd.getdummies

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)
pd.get_dummies(visa_df,columns=['continent'],dtype=int)
# Out:
#          case_id education_of_employee has_job_experience  \
# 0         EZYV01           High School                  N
# 1         EZYV02              Master's                  Y
# 2         EZYV03            Bachelor's                  N
# 3         EZYV04            Bachelor's                  N
# 4         EZYV05              Master's                  Y
# ...          ...                   ...                ...
# 25475  EZYV25476            Bachelor's                  Y
# 25476  EZYV25477           High School                  Y
# 25477  EZYV25478              Master's                  Y
# 25478  EZYV25479              Master's                  Y
# 25479  EZYV25480            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...
