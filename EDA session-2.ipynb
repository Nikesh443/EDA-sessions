# %% [markdown]
# ## step-1 Import all the packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step-2: Read the data

# %%
file_path="C:\\Users\\pc\\Documents\\Visadataset.csv"
visa_df=pd.read_csv(file_path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $shape$

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print('The number of rows are:',visa_df.shape[0])
# Out:
# The number of rows are: 25480

# %%
print('The number of columns are:',visa_df.shape[1])
# Out:
# The number of columns are: 12

# %%
#<package_name>.<method_name>()

# %%
visa_df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 visa_df.shape()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# - Functions are used to call
# - Function means()
# - not callbel means, remove the brackets

# %% [markdown]
# $ size$

# %%
visa_df.size
# number of rows * number of coluns
# Out:
# 305760

# %% [markdown]
# $ columns$

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
visa_df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')>

# %% [markdown]
# - bound method means use the brackets.
# - not callable means remove the brackets.

# %%
visa_df.columns.to_list()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
dict()========= to_dict
list()========== to_list

# %%
# Another way
list(visa_df.columns)
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# $dttypes$

# %%
visa_df.dtypes

# object======> categorical column
# int64 and float64=========> Numericalcolumn
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
visa_df.dtypes.index
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
type(visa_df.dtypes.values)
# numpy n dimensions array
# Out:
# numpy.ndarray

# %%
list1=[1,2,3,4]
list1
# Out:
# [1, 2, 3, 4]

# %%
np.array([1,2,3])+np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %%
array[]=====> numpy
index[]======> pandas index
pandas.dataframe
pandas.series

# %% [markdown]
# ## task-1

# %%
# separate categorical columns and numerical columns in list
  # create two list
# cat
# numerical

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dict(visa_df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
for i,j in dict(visa_df.dtypes).items():
    print(i)
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# no_of_employees
# yr_of_estab
# region_of_employment
# prevailing_wage
# unit_of_wage
# full_time_position
# case_status

# %%
#for i,j in dict(visa_df.dtypes).items():
    #if j=='object':
        #print(i)

cat=[key for key,value in dict(visa_df.dtypes).items() if value=='object']
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# $head$

# %%
visa_df.head() # top 5 rows
# starting with index zer0
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# For top 2
visa_df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %% [markdown]
# $ tail$

# %%
visa_df.tail()
# Last five rows
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# $ take$

# %%
# Here in take default axis=0
list1=[100,200,500]
visa_df.take(list1)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 500  EZYV501      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 500                     N             1245         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 500         92549.52         Year                  N   Certified

# %%
list1=[1,4,7]
visa_df.take(list1,axis=1)
# in python index starts with zer0
# 1=========== 2nd column
# 4=========== 5th column
# 7=========== 8th column
# Out:
#       continent requires_job_training region_of_employment
# 0          Asia                     N                 West
# 1          Asia                     N            Northeast
# 2          Asia                     Y                 West
# 3          Asia                     N                 West
# 4        Africa                     N                South
# ...         ...                   ...                  ...
# 25475      Asia                     Y                South
# 25476      Asia                     N            Northeast
# 25477      Asia                     N                South
# 25478      Asia                     Y                 West
# 25479      Asia                     N              Midwest
#
# [25480 rows x 3 columns]

# %% [markdown]
# $ task-2$

# %%
# I want 150,300,450 rows from 5,8,12 column
list1=[150,300,450]
list2=[4,7,11]
visa_df.take(list2,axis=1).take(list1)
# Out:
#     requires_job_training region_of_employment case_status
# 150                     N                 West      Denied
# 300                     N              Midwest   Certified
# 450                     Y                 West      Denied

# %% [markdown]
# $ i loc and loc$

# %%
visa_df.iloc[<rows>,<columns>]
visa_df.iloc[start:end,start:end]

# %%
visa_df.iloc[100:151]  # all the columns
# Out:
#      case_id      continent education_of_employee has_job_experience  \
# 100  EZYV101           Asia              Master's                  Y
# 101  EZYV102           Asia              Master's                  Y
# 102  EZYV103           Asia            Bachelor's                  Y
# 103  EZYV104           Asia             Doctorate                  Y
# 104  EZYV105           Asia              Master's                  Y
# 105  EZYV106  North America             Doctorate                  Y
# 106  EZYV107           Asia            Bachelor's                  N
# 107  EZYV108           Asia            Bachelor's                  Y
# 108  EZYV109           Asia            Bachelor's                  N
# 109  EZYV110           Asia            Bachelor's                  Y
# 110  EZYV111  North America           High School                  Y
# 111  EZYV112           Asia              Master's                  Y
# 112  EZYV113           Asia            Bachelor's                  Y
# ...

# %%
visa_df.iloc[50:56,0:6]
# Out:
#    case_id continent education_of_employee has_job_experience  \
# 50  EZYV51      Asia            Bachelor's                  N
# 51  EZYV52      Asia              Master's                  Y
# 52  EZYV53      Asia            Bachelor's                  N
# 53  EZYV54      Asia           High School                  Y
# 54  EZYV55      Asia              Master's                  Y
# 55  EZYV56      Asia              Master's                  Y
#
#    requires_job_training  no_of_employees
# 50                     N              746
# 51                     N             3129
# 52                     N             1647
# 53                     N             2438
# 54                     N            11733
# 55                     N             2368

# %%
visa_df.iloc[[100,106,108],[5,8,3]]
# Out:
#      no_of_employees  prevailing_wage has_job_experience
# 100             2227         28243.79                  Y
# 106              890         64137.41                  N
# 108             2903         97520.02                  N

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# I want 100,200,300 from only case status column 
visa_df.iloc[[100,200,300],11]
# Out:
# 100    Certified
# 200    Certified
# 300    Certified
# Name: case_status, dtype: object

# %%
visa_df.iloc[[100,200,300],'case_status']

# iloc will take only numbers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 visa_df.iloc[[100,200,300],'case_status']
#
# ...

# %%
# list of rows
# list of columns
visa_df.loc[[100,103,104],['case_status','continent']]
# In loc we can use categorical columns also
# Out:
#     case_status continent
# 100   Certified      Asia
# 103   Certified      Asia
# 104   Certified      Asia

# %%
- shape
- size
- dtypes
- columns
- we separated cat and num columns
- head
- tail
- take
- iloc
- loc
- is null
- info

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# $ is null$

# %%
# any missing values are there in the data
# is null === you re asking to the computer
# answe will be true/false
# if data presents/no missing values: False
# if any missing values are there it is true

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# $info$

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
## Revision

# %%
Empirical rule:if follows normal distribution,
       68-95-99.7

If doesnot follow normal distribution then: chebyshev rule
(1-1/k**2)
k=2 ==========>(1-1/2**2)====3/4======75%
k=1 ===========> 0% data



variance: how the data is varying

wages: 5000rs       5 lakh rupees
       5000     60000
        1ob      2ob
In order to understand the data flow: variance

variance is for single column

covariance:  How a data vary in one column w.r.t to another column

- covariance will explain about the relation between two columns(positive,negative or no relation) but it will not tell about how much


In order to know how we have,

correlation:
=> It helps to determine how much relation is there between the columns
=> It ranges [0,1]


r=cov(x,y)/sigma(x)*sigma(y)

correlation value between age and income is o.7
==> It means age and income have 70% positive relation

# %%
standarization:
1)z-score
2)Normalization

#####z-score######

age       income
30        100000
31        200000

one column very less values
second value has very huge values

age: -3 to 3
income: -3 to 3

we convert by using z-score

z-score=(x-mean)/sigma

#### Normalization######


normalization=(x-xmin)/(xmax-xmin)
range[0,1]


curse of dimensionality:

  when the dimension increases 
  computation requires more
  time more
  memory more
  Drawbacks

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\pc\\Desktop\\Data Science\\EDA python'

# %%
# Here concatenation will work
os.getcwd()+"\\outputs"
# Out:
# 'C:\\Users\\pc\\Desktop\\Data Science\\EDA python\\outputs'

# %%
'a'+'b'
# Out:
# 'ab'

# %%
stat1: EDA: interview
stat2: probability(ML model)
stat3: hypothesis testing, sampling theorem, CI z,t,f test
